# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

llm = ChatGroq(
    groq_api_key="",
    model="llama-3.1-8b-instant"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("user", "{question}")
])

chain = prompt | llm
response = chain.invoke({"question": "what is the capital of warangal."})

print(response.content)
# Out:
# Warangal is a city in the Indian state of Telangana. Warangal was the capital of the Kakatiya dynasty in the 12th and 13th centuries.
#
# However, the current administrative division is Warangal district which was divided into two districts, Warangal Urban and Warangal Rural in 2016.
#
# The capital of Telangana is Hyderabad, but the city of Warangal does not have a capital in the sense that it is not the capital of a separate state or union territory.

# %%
chain.invoke({"question": "what is AI."}).content
# Out:
# 'AI stands for Artificial Intelligence, which refers to the development of computer systems that can perform tasks that typically require human intelligence. This includes:\n\n1. **Learning**: AI systems can learn from data, experiences, and environments.\n2. **Reasoning**: AI systems can make decisions, solve problems, and draw conclusions based on data and logic.\n3. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n4. **Action**: AI systems can interact with the physical world, such as controlling robots or autonomous vehicles.\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: These systems are designed to perform a specific task, such as image recognition, speech recognition, or playing chess.\n2. **General or Strong AI**: These systems have the ability to understand, learn, and apply knowledge across a wide range of tasks.\n3. **Superintelligence**: These systems have intelligence far beyond that of the best human minds.\n\nAI can be applied in various fields, such as:\n\n1. **Healthcare**: AI can help diagnose diseases, develop personalized treatment plans, and automate administrative tasks.\n2. **Finance**: AI can analyze markets, predict trends, and automate trading.\n3. **Transportation**: AI can control self-driving cars, optimize traffic flow, and improve logistics.\n4. **Education**: AI can personalize learning experiences, grade assignments, and provide feedback.\n5. **Customer Service**: AI can respond to customer inquiries, route calls, and provide support.\n\nThe benefits of AI include:\n\n1. **Increased efficiency**: AI can automate tasks, freeing up human resources for more strategic work.\n2. **Improved accuracy**: AI can reduce errors and improve decision-making.\n3. **Enhanced customer experience**: AI can provide personalized experiences, respond to customer inquiries, and improve customer satisfaction.\n4. **Increased productivity**: AI can help humans focus on higher-level tasks, leading to increased productivity and innovation.\n\nHowever, AI also raises concerns about:\n\n1. **Job displacement**: AI may automate jobs, potentially displacing human workers.\n2. **Bias and fairness**: AI systems can perpetuate biases and inequalities if not designed with fairness and transparency in mind.\n3. **Security and privacy**: AI systems can be vulnerable to cyber attacks and data breaches, compromising personal data and security.\n4. **Accountability**: AI systems can be difficult to hold accountable for their actions, leading to questions about liability and responsibility.\n\nOverall, AI has the potential to revolutionize many industries and aspects of life, but it also requires careful consideration and responsible development to ensure its benefits are equitably distributed and its risks are mitigated.'

# %%
chain.invoke({"question": "what is capital of france."}).content
# Out:
# 'The capital of France is Paris.'
